-- %%
-- select * from `workspace`.`bronze`.`eficiencia_energetica_a/Volumes/workspace/bronze/yeikragon` limit 100;

-- Querying nested fields using dot notation for STRUCT types
SELECT 
  order_id, 
  customer.name AS customer_name, 
  items[0] AS primary_item 
FROM json.`/Volumes/workspace/bronze/yeik/Exa_Unstr_Dat.json`;


-- 2. Create the Bronze table using your JSON logic
CREATE TABLE workspace.bronze.orders_raw
AS SELECT 
  order_id, 
  customer.name AS customer_name, 
  items[0] AS primary_item,
  _metadata.file_path AS source_file  -- Helpful for auditing in Bronze
FROM json.`/Volumes/workspace/bronze/yeik/Exa_Unstr_Dat.json`;


-- 3. Verify the table is now a Delta table
DESCRIBE TABLE EXTENDED workspace.bronze.orders_raw;



-- Normalizing a "NoSQL" style document into a flat list
SELECT 
  order_id, 
  customer.name AS customer_name, 
  exploded_item AS item
FROM json.`/Volumes/workspace/bronze/yeik/Exa_Unstr_Dat.json`
LATERAL VIEW explode(items) AS exploded_item;
