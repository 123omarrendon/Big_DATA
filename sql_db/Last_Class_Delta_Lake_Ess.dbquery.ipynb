-- %%
CREATE TABLE IF NOT EXISTS workspace.bronze.inventory (id INT, item STRING, stock INT) USING DELTA;

INSERT INTO workspace.bronze.inventory VALUES (1, 'Keyboard', 50), (2, 'Mouse', 100);

UPDATE workspace.bronze.inventory SET stock = stock - 10 WHERE id = 1;

-- View the history of changes
DESCRIBE HISTORY workspace.bronze.inventory;
