-- %%
-- 1. Create a Catalog for the class
--CREATE CATALOG IF NOT EXISTS workspace;
--USE CATALOG workspace;

-- 2. Create a Schema (Database)
--CREATE SCHEMA IF NOT EXISTS bronze;

-- 3. Create a table with a Row Filter (Governance)
-- Only 'Managers' can see income upper $100000
--CREATE TABLE income_filter (id INT, amount DOUBLE);
CREATE OR REPLACE FUNCTION workspace.bronze.income_filter(income DOUBLE)
RETURNS BOOLEAN
RETURN is_account_group_member('managers') OR income > 100000;


-- Then apply the row filter to the table
ALTER TABLE workspace.bronze.credit_risk_raw SET ROW FILTER workspace.bronze.income_filter ON (person_income);
