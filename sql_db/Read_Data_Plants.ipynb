# %%
import os

# Usamos la nueva variable que pide Kaggle en tu imagen
os.environ['KAGGLE_USERNAME'] = "yeistabordahenao" # Tu usuario (basado en tus datos)
os.environ['KAGGLE_API_TOKEN'] = "KGAT_27cfc47e1603e7c1050f8cde774307f3"

print("Autenticación configurada. Listos para cargar data no estructurada.")

# %%
# %sh
# Limpiar e intentar la descarga con las variables de entorno heredadas de Python
rm -rf /tmp/plants_raw /tmp/plants_unzipped
mkdir -p /tmp/plants_raw /tmp/plants_unzipped

# Descarga directa (usando las variables de entorno de arriba)
kaggle competitions download -c plant-pathology-2021-fgvc8 -p /tmp/plants_raw

# Descomprimir y mover al volumen
unzip -q /tmp/plants_raw/*.zip -d /tmp/plants_unzipped
mkdir -p /Volumes/workspace/bronze/yeik/plants/
cp -r /tmp/plants_unzipped/* /Volumes/workspace/bronze/yeik/plants/

echo "¡Carga completada!"

# %%
ls /Volumes/workspace/bronze/yeik/plants/

# %%
# %sh
# 1. Crear la carpeta que falta
mkdir -p /Volumes/workspace/bronze/yeik/plants/new_uploads/

# 2. Simular la llegada de nuevos datos (Copiamos 5 imágenes al azar)
# Esto es para que el SQL tenga algo que leer y no falle
cp $(ls /Volumes/workspace/bronze/yeik/plants/train_images/*.jpg | head -n 5) /Volumes/workspace/bronze/yeik/plants/new_uploads/

echo "Carpeta creada y datos de prueba cargados."
